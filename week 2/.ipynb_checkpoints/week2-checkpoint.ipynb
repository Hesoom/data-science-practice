# %% [markdown]
# # Week 2

# %%
import pandas as pd
import sqlite3

# Load the two CSV files
orders = pd.read_csv('../dataset/olist_orders_dataset.csv')
customers = pd.read_csv('../dataset/olist_customers_dataset.csv')
products = pd.read_csv('../dataset/olist_products_dataset.csv')
payments = pd.read_csv('../dataset/olist_order_payments_dataset.csv')

# Create an in-memory SQL database and load them in
conn = sqlite3.connect(':memory:')
orders.to_sql('orders', conn, index=False)
customers.to_sql('customers', conn, index=False)
products.to_sql('products', conn, index=False)

print("Ready. Tables loaded.")
# Out:
# Ready. Tables loaded.

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# ## Delivery Time

# %%
merged = orders.merge(customers, on='customer_id', how='inner')

# %%
merged.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
type(merged.order_delivered_customer_date[0])
# Out:
# str

# %%
merged['order_delivered_customer_date'] = pd.to_datetime(merged.order_delivered_customer_date)
merged['order_purchase_timestamp'] = pd.to_datetime(merged.order_purchase_timestamp)

# %%
type(merged.order_delivered_customer_date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
delivery_time = merged.order_delivered_customer_date - merged.order_purchase_timestamp

# %%
delivery_time.dt.days
# Out:
# 0         8.0
# 1        13.0
# 2         9.0
# 3        13.0
# 4         2.0
#          ...
# 99436     8.0
# 99437    22.0
# 99438    24.0
# 99439    17.0
# 99440     7.0
# Length: 99441, dtype: float64

# %%
merged["delivery_time"] = delivery_time.dt.days

# %%
merged.delivery_time
# Out:
# 0         8.0
# 1        13.0
# 2         9.0
# 3        13.0
# 4         2.0
#          ...
# 99436     8.0
# 99437    22.0
# 99438    24.0
# 99439    17.0
# 99440     7.0
# Name: delivery_time, Length: 99441, dtype: float64

# %%
# Average delivery time in each city
merged.groupby("customer_city")['delivery_time'].mean().sort_values(ascending=False)
# Out:
# customer_city
# novo brasil                 148.00
# capinzal do norte           109.00
# adhemar de barros            97.00
# arace                        85.75
# marcelino vieira             78.00
#                              ...
# santo antonio de goias         NaN
# sao domingos do sul            NaN
# sao fernando                   NaN
# sao francisco do humaita       NaN
# sao joao do itaperiu           NaN
# Name: delivery_time, Length: 4119, dtype: float64

# %% [markdown]
# ## Late Delivery

# %%
orders['order_delivered_customer_date'] = pd.to_datetime(orders.order_delivered_customer_date)
orders['order_estimated_delivery_date'] = pd.to_datetime(orders.order_estimated_delivery_date)

# %%
orders.order_delivered_customer_date > orders.order_estimated_delivery_date
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99436    False
# 99437    False
# 99438    False
# 99439    False
# 99440    False
# Length: 99441, dtype: bool

# %%
# Count and percentage of orders delivered later than the estimated delivery date

n_late = (orders.order_delivered_customer_date > orders.order_estimated_delivery_date).sum()
percentage = n_late * 100 / orders.shape[0]

print("Numbers of late deliveries: ",n_late)
print("percentage of the late deliveries",percentage)
# Out:
# Numbers of late deliveries:  7827
# percentage of the late deliveries 7.87099888376022

# %% [markdown]
# ## Highest Revenue

# %%
merged = merged.merge(payments, on='order_id', how='inner')
merged.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Getting highest revenue on states
merged.groupby('customer_state')['payment_value'].sum().sort_values(ascending=False)
# Out:
# customer_state
# SP    5998226.96
# RJ    2144379.69
# MG    1872257.26
# RS     890898.54
# PR     811156.38
# SC     623086.43
# BA     616645.82
# DF     355141.08
# GO     350092.31
# ES     325967.55
# PE     324850.44
# CE     279464.03
# PA     218295.85
# MT     187029.29
# MA     152523.02
# PB     141545.72
# MS     137534.84
# PI     108523.97
# RN     102718.13
# AL      96962.06
# SE      75246.25
# TO      61485.33
# RO      60866.20
# AM      27966.93
# AC      19680.62
# AP      16262.80
# RR      10064.62
# Name: payment_value, dtype: float64

# %% [markdown]
# ## Top 5 product categories

# %%
order_items = pd.read_csv("../dataset/olist_order_items_dataset.csv")
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_product = order_items.merge(products,on='product_id',how='inner')
order_product.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
# Top 5 product categories
order_product.groupby('product_category_name').size().sort_values(ascending=False).iloc[:5]
# Out:
# product_category_name
# cama_mesa_banho           11115
# beleza_saude               9670
# esporte_lazer              8641
# moveis_decoracao           8334
# informatica_acessorios     7827
# dtype: int64

# %% [markdown]
# ## For each city, what's the most-ordered product category?

# %%
customer_product = customers.merge(orders,on='customer_id',how='inner')
customer_product = customer_product.merge(order_items, on='order_id',how='inner')
customer_product = customer_product.merge(products, on='product_id',how='inner')

# %%
customer_product.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
counts = customer_product.groupby(['customer_city','product_category_name']).size().reset_index(name='order_count')

# %%
# For each city, what's the most-ordered product category?
counts.sort_values('order_count', ascending=False).drop_duplicates('customer_city')
# Out:
#            customer_city   product_category_name  order_count
# 21850          sao paulo         cama_mesa_banho         1984
# 19084     rio de janeiro         cama_mesa_banho          854
# 2611      belo horizonte         cama_mesa_banho          351
# 3274            brasilia            beleza_saude          246
# 17887       porto alegre         cama_mesa_banho          175
# ...                  ...                     ...          ...
# 10428  itaguacu da bahia            beleza_saude            1
# 10590            itamari      relogios_presentes            1
# 10607            itamogi      ferramentas_jardim            1
# 10529   itaju do colonia               telefonia            1
# 25220             zortea  informatica_acessorios            1
#
# [4095 rows x 3 columns]

# %% [markdown]
# ## Does delivery time affect review score?

# %%
order_reviews = pd.read_csv('../dataset/olist_order_reviews_dataset.csv')
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
merged = order_reviews.merge(orders,on='order_id',how='inner')

# %%
merged.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
merged['late_delivery'] = merged.order_delivered_customer_date > merged.order_estimated_delivery_date

# %%
# get average review scores based on late delivery
merged.groupby('late_delivery')['review_score'].mean().reset_index()
# Out:
#    late_delivery  review_score
# 0          False      4.214307
# 1           True      2.566550

# %% [markdown]
# ## How has average order value changed month over month?

# %%
order_payment = orders.merge(payments, on='order_id', how='inner')
order_payment.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_payment['order_date_month'] = pd.to_datetime(order_payment['order_purchase_timestamp']).dt.to_period('M')

# %%
# What is the average of order value of each month
order_payment.groupby('order_date_month')['payment_value'].mean().sort_index().reset_index()
# Out:
#    order_date_month  payment_value
# 0           2016-09      84.080000
# 1           2016-10     172.779181
# 2           2016-12      19.620000
# 3           2017-01     162.927106
# 4           2017-02     154.776251
# 5           2017-03     158.570180
# 6           2017-04     162.500206
# 7           2017-05     150.334386
# 8           2017-06     148.799878
# 9           2017-07     137.220968
# 10          2017-08     148.218971
# 11          2017-09     161.152004
# 12          2017-10     160.427547
# 13          2017-11     151.962711
# 14          2017-12     149.007885
# 15          2018-01     147.428822
# 16          2018-02     142.759399
# 17          2018-03     154.373285
# 18          2018-04     161.018932
# 19          2018-05     161.735410
# 20          2018-06     159.507789
# 21          2018-07     163.906677
# 22          2018-08     152.646360
# 23          2018-09     277.471250
# 24          2018-10     147.417500

# %% [markdown]
# ## How does average review score vary by city?

# %%
merged = merged.merge(customers, on='customer_id')

# %%
merged.groupby('customer_city')['review_score'].mean().sort_values(ascending=False).reset_index()
# Out:
#             customer_city  review_score
# 0     abadia dos dourados           5.0
# 1       riachao das neves           5.0
# 2          caxambu do sul           5.0
# 3            retirolandia           5.0
# 4           restinga seca           5.0
# ...                   ...           ...
# 4112             macaubal           1.0
# 4113    antonina do norte           1.0
# 4114             guairaca           1.0
# 4115                guape           1.0
# 4116              ouvidor           1.0
#
# [4117 rows x 2 columns]

# %% [markdown]
# ## Which sellers have the highest late-delivery rate

# %%
sellers = pd.read_csv('../dataset/olist_sellers_dataset.csv')
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
seller_order = sellers.merge(order_items,on='seller_id')
seller_order = seller_order.merge(orders,on='order_id')
seller_order.head()
# Out:
#                           seller_id  seller_zip_code_prefix seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 1  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 2  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 3  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
# 4  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
#
#   seller_state                          order_id  order_item_id  \
# 0           SP  4a90af3e85dd563884e2afeab1091394              1
# 1           SP  6d953888a914b67350d5bc4d48f2acab              1
# 2           SP  bc8a5de6abf5b14f98a6135a7fb46731              2
# 3           SP  035201c3c82a97f8a25dd6bd5244b2d5              1
# 4           SP  0504447548229e075dea8441b37b1e2a              1
#
#                          product_id  shipping_limit_date   price  \
# 0  ffb64e34a37740dafb6c88f1abd1fa61  2017-08-25 20:50:19  106.20
# ...

# %%
seller_order['order_estimated_delivery_date'] = pd.to_datetime(seller_order.order_estimated_delivery_date)
seller_order['order_delivered_customer_date'] = pd.to_datetime(seller_order.order_delivered_customer_date)
seller_order['late_delivery'] = seller_order.order_estimated_delivery_date < seller_order.order_delivered_customer_date
seller_order['late_delivery']
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 112645    False
# 112646    False
# 112647    False
# 112648    False
# 112649    False
# Name: late_delivery, Length: 112650, dtype: bool

# %%
(seller_order.groupby('seller_id')['late_delivery'].mean() * 100).sort_values(ascending=False).reset_index()
# Out:
#                              seller_id  late_delivery
# 0     da2782c804606d2a5d8e1760dbb3e7ec          100.0
# 1     8e670472e453ba34a379331513d6aab1          100.0
# 2     154bdf805377afea75a3bd158e9eab10          100.0
# 3     586a871d4f1221763fddb6ceefdeb95e          100.0
# 4     80ceebb4ee9b31afb6c6a916a574a1e2          100.0
# ...                                ...            ...
# 3090  6b9b80d53ba3676eafe60268a810b5a1            0.0
# 3091  6b89abe95848c850399130d149a39b63            0.0
# 3092  6b803197e03abd5056b4313306b4f29d            0.0
# 3093  6b2612338467c08c9b25f0cc55b1578d            0.0
# 3094  ffff564a4f9085cd26170f4732393726            0.0
#
# [3095 rows x 2 columns]

# %% [markdown]
# ## Are customers in some regions paying more for shipping?

# %%
item_customer = order_items.merge(orders,on='order_id')
item_customer = item_customer.merge(customers,on='customer_id')
item_customer.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  \
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# ...

# %%
item_customer['freight_price_ratio'] = item_customer.freight_value / item_customer.price

# %%
item_customer.groupby('customer_state')['freight_price_ratio'].mean().sort_values(ascending=False).reset_index()
# Out:
#    customer_state  freight_price_ratio
# 0              RO             0.594188
# 1              RR             0.589050
# 2              MA             0.549324
# 3              AC             0.511651
# 4              PB             0.511597
# 5              RN             0.506330
# 6              PI             0.499842
# 7              TO             0.499459
# 8              AM             0.498136
# 9              AL             0.474482
# 10             PA             0.473593
# 11             SE             0.464946
# 12             PE             0.449996
# 13             CE             0.431541
# 14             BA             0.394946
# 15             MT             0.393178
# 16             AP             0.384499
# 17             RS             0.355787
# 18             ES             0.352253
# 19             GO             0.351613
# 20             SC             0.346031
# 21             PR             0.344956
# 22             DF             0.343084
# ...
